# %% [markdown]
# # NOTEBOOK 6b: ANALISI COUNTERFACTUALS
#
#
# - fare (df con y_min, y_white, differenza e poi) media differenza per tutti i modelli

# %%
# IMPORTING STATEMENTS
import sys
import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import platform
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats


np.random.seed(7)


print(f"Python Platform: {platform.platform()}")
print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: macOS-13.2.1-arm64-arm-64bit
# Tensor Flow Version: 2.12.0
# Keras Version: 2.12.0
#
# Python 3.10.10 | packaged by conda-forge | (main, Mar 24 2023, 20:12:31) [Clang 14.0.6 ]
# Pandas 2.1.1
# Scikit-Learn 1.3.1
# GPU is available

# %% [markdown]
# # Import Data and Preparation

# %%
# DF FINALE 

counterf = pd.read_csv('TEST_DATA_gender.csv')

# %%
# Import Predictions
path = 'predictions_gender/'    # path of folder

# %%
models = ['LinearRegression', 'RandomForest', 'XGBoost', 'LightGBM','HybridModel','Stacking']
y_preds = []

for model in models:
    y_preds.append( pd.read_csv(str(path)+str(model)+'_pred.csv', header=None).loc[:,0])

# %%
y_preds[0]
# Out:
# 0      -3.222800e+09
# 1      -3.222800e+09
# 2      -3.222800e+09
# 3      -3.222800e+09
# 4      -3.222800e+09
#             ...
# 4495    3.781332e+00
# 4496    2.888615e+00
# 4497    3.478479e+00
# 4498    2.284192e+00
# 4499    2.891445e+00
# Name: 0, Length: 4500, dtype: float64

# %%
counterf.reset_index(drop=True, inplace=True)

# %%
y_true = counterf.pop('InterestRate')

# %%
y_true
# Out:
# 0       4.500
# 1       5.000
# 2       2.625
# 3       3.625
# 4       3.750
#         ...
# 4495    4.000
# 4496    2.875
# 4497    3.000
# 4498    2.750
# 4499    2.875
# Name: InterestRate, Length: 4500, dtype: float64

# %%
list(counterf.columns)
# Out:
# ['Unnamed: 0',
#  'MinorityRatio',
#  'CensusTractMedFamIncome',
#  'MonthlyIncome',
#  'HUDMedIncome',
#  'LTV',
#  'PaymentCount',
#  'Age1',
#  'Age2',
#  'HousingExpense',
#  'DebtExpense',
#  'PMI',
#  'CreditScore1',
#  'CreditScore2',
#  'NoteDate',
#  'NoteAmount',
#  'BorrowerCount',
#  'FirstTime',
#  'SelfEmployed',
#  'Bank_Boston',
#  'Bank_Chicago',
#  'Bank_Cincinnati',
#  'Bank_Dallas',
#  'Bank_Des Moines',
#  'Bank_Indianapolis',
#  'Bank_Pittsburgh',
#  'Bank_Topeka',
#  'Bank_infrequent_sklearn',
#  'LoanPurpose_1',
#  'LoanPurpose_2',
#  'LoanPurpose_6',
#  'MortgageType_0',
#  'MortgageType_infrequent_sklearn',
#  'Gender1_1',
#  'Gender1_2',
#  'Gender1_3',
#  'Gender2_1',
#  'Gender2_2',
#  'Gender2_3',
#  'Gender2_4',
#  'PropertyType_1',
#  'PropertyType_6',
#  'PropertyType_7',
#  'PropertyType_infrequent_sklearn',
#  'Race1_2',
#  'Race1_5',
#  'Race1_6',
#  'Race1_infrequent_sklearn',
#  'Minority2_Min',
#  'Minority2_Missing',
#  'Minority2_White',
#  'Race2_5',
#  'Race2_6',
#  'Race2_8',
#  'Race2_infrequent_sklearn',
#  'State_6',
#  'State_8',
#  'State_17',
#  'State_18',
#  'State_19',
#  'State_20',
#  'State_26',
#  'State_27',
#  'State_29',
#  'State_31',
#  'State_39',
#  'State_42',
#  'State_48',
#  'State_55',
#  'State_infrequent_sklearn',
#  'Minority_Min',
#  'Minority_Missing',
#  'Minority_White',
#  'Borrower2Dummy']

# %%
idx_min = counterf[counterf['Gender1_1']==1].index
idx_miss = counterf[counterf['Gender1_2']==1].index
idx_white = counterf[counterf['Gender1_3']==1].index

# %% [markdown]
# # PLOT RESULTS: MODIFICARE!!!

# %%
models
# Out:
# ['LinearRegression',
#  'RandomForest',
#  'XGBoost',
#  'LightGBM',
#  'HybridModel',
#  'Stacking']

# %%
colors_true=['DarkRed','DarkBlue', 'DarkGreen']
colors=['Crimson', 'DodgerBlue', 'Green']
titles=['Male','Female','Missing']
indices=[idx_min, idx_white, idx_miss]

# %%
def create_subplots(models, y_preds, y_true, indices, colors, colors_true, titles):
    for j, model in enumerate(models):
        y_pred = y_preds[j]

        plt.figure(figsize=(8, 7))
        plt.suptitle(model)

        # Create plot
        for i, idx in enumerate(indices):
                        
            # Select, sort the data and get the sorted indices
            y_pred_sel, y_true_sel = y_pred[idx], y_true[idx]
            sorted_indices = np.argsort(y_true_sel)

            # Sort y_true and y_pred based on the sorted indices
            y_true_sorted = np.array(y_true_sel)[sorted_indices]
            y_pred_sorted = np.array(y_pred_sel)[sorted_indices]

            # Create a scatterplot
            plt.scatter(range(len(y_true_sorted)), y_pred_sorted, c=colors[i], marker='o', label=titles[i], alpha=0.5, s=4)
        if i==len(indices)-1:
            plt.scatter(range(len(y_true_sorted)), y_true_sorted, c='black', marker='s', label='True Value', alpha=1, s=3)
            plt.xlabel('Sorted Index')
            plt.ylabel('Interest Rate')
            plt.legend(loc='upper left')
            plt.grid(True)
            plt.tight_layout()

        plt.show();
        plt.clf()

# %%
create_subplots(models, y_preds, y_true, indices[:-1], colors, colors_true, titles)

# %% [markdown]
# For stacking, it is possible to identify some points that have higher interest rate predictions for minority applicants than for white applicants. This is especially true for the middle-high range of interest rates, suggesting that ethnicity plays a bigger role when the applicant is already belonging to a higher-risk category because of other factors than minority status.
# At the same time, this trend is not always consistent, so no conclusions can be made.

# %% [markdown]
# ### fare (df con y_min, y_white, differenza e poi) media differenza per tutti i modelli

# %%
import numpy as np
import pandas as pd
from scipy import stats

avg_diffs, ttests = [], []
diffs, t_statistic, p_value, pair, names = [], [], [], [], []

for i, model in enumerate(models):
    #print(model)
    y_pred = y_preds[i]
    avg_diffs.append([
        np.mean(np.array(y_pred[idx_min]) - np.array(y_pred[idx_white])),
        np.mean(np.array(y_pred[idx_min]) - np.array(y_pred[idx_miss])),
        np.mean(np.array(y_pred[idx_miss]) - np.array(y_pred[idx_white])),
        model ])
    
    # Perform t-tests
    for j in range(len(indices)):
        for k in range(j + 1, len(indices)):
            #print(j,k)
            diff = np.mean(np.array(y_pred[indices[j]]) - np.array(y_pred[indices[k]]))
            t_stat, p_val = stats.ttest_ind(y_pred[indices[j]], y_pred[indices[k]])
            t_statistic.append(t_stat)
            p_value.append(p_val)
            pair.append(str(titles[j])+'-'+str(titles[k]))
            names.append(model)
            diffs.append(diff)
    #ttests.append( [t_statistic, p_value, pair, [model]*3])

# Create a DataFrame for the average differences
avg_diffs_df = pd.DataFrame(avg_diffs, columns=['AvgDiff_Min_White', 'AvgDiff_Min_Miss', 'AvgDiff_Miss_White', 'Model'])
ttest_diffs_df = pd.DataFrame([diffs, t_statistic, p_value, pair, names], index=['Difference','t_statistic', 'p_value', 'Pair', 'Model'])#, columns=['T_Min_White', 'T_Min_Miss', 'T_Miss_White', 'Model'])

# %%
# Display the DataFrame
pd.options.display.float_format = '{:.6f}'.format

avg_diffs_df#['AvgDiff_Min_White'].apply(lambda x: '%.6f' % x)
# Out:
#    AvgDiff_Min_White  AvgDiff_Min_Miss  AvgDiff_Miss_White             Model
# 0 -3222799750.795904 3021896685.006815  -6244696435.802719  LinearRegression
# 1           0.001651          0.000567            0.001084      RandomForest
# 2          -0.000840         -0.000840            0.000000           XGBoost
# 3           0.000008          0.000008            0.000000          LightGBM
# 4           0.000065         -0.000225            0.000290       HybridModel
# 5           0.002536          0.001914            0.000622          Stacking

# %%
results = ttest_diffs_df.T

# %%
import helper_functions_fs as hf

def format_df_green(s, green_value=0.05):
    if type(s)==str: color = 'white'
    else:
        if s <= green_value: color = 'lightgreen'
        else: color = 'white'
    return 'background-color: %s' % color

# %%
results.style.applymap(format_df_green)
# Out:
# /var/folders/p_/77946ggd5fs5m05m058z3hp40000gn/T/ipykernel_80900/843840761.py:1: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   results.style.applymap(format_df_green)
# <style type="text/css">
# #T_ba1fa_row0_col0, #T_ba1fa_row0_col1, #T_ba1fa_row0_col2, #T_ba1fa_row1_col2, #T_ba1fa_row2_col2, #T_ba1fa_row3_col0, #T_ba1fa_row4_col0, #T_ba1fa_row4_col1, #T_ba1fa_row5_col0, #T_ba1fa_row5_col1, #T_ba1fa_row6_col0, #T_ba1fa_row6_col1, #T_ba1fa_row7_col0, #T_ba1fa_row7_col1, #T_ba1fa_row8_col0, #T_ba1fa_row8_col1, #T_ba1fa_row9_col0, #T_ba1fa_row9_col1, #T_ba1fa_row10_col0, #T_ba1fa_row10_col1, #T_ba1fa_row11_col0, #T_ba1fa_row11_col1, #T_ba1fa_row12_col0, #T_ba1fa_row12_col1, #T_ba1fa_row13_col0, #T_ba1fa_row13_col1, #T_ba1fa_row14_col0, #T_ba1fa_row14_col1, #T_ba1fa_row15_col0, #T_ba1fa_row16_col0, #T_ba1fa_row17_col0, #T_ba1fa_row17_col1 {
#   background-color: lightgreen;
# }
# #T_ba1fa_row0_col3, #T_ba1fa_row0_col4, #T_ba1fa_row1_col0, #T_ba1fa_row1_col1, #T_ba1fa_row1_col3, #T_ba1fa_row1_col4, #T_ba1fa_row2_col0, #T_ba1fa_row2_col1, #T_ba1fa_row2_col3, #T_ba1fa_row2_col4, #T_ba1fa_row3_col1, #T_ba1fa_row3_col2, #T_ba1fa_row3_col3, #T_ba1fa_row3_col4, #T_ba1fa_row4_col2, #T_ba1fa_row4_col3, #T_ba1fa_row4_col4, #T_ba1fa_row5_col2, #T_ba1fa_row5_col3, #T_ba1fa_row5_col4, #T_ba1fa_row6_col2, #T_ba1fa_row6_col3, #T_ba1fa_row6_col4, #T_ba1fa_row7_col2, #T_ba1fa_row7_col3, #T_ba1fa_row7_col4, #T_ba1fa_row8_col2, #T_ba1fa_row8_col3, #T_ba1fa_row8_col4, #T_ba1fa_row9_col2, #T_ba1fa_row9_col3, #T_ba1fa_row9_col4, #T_ba1fa_row10_col2, #T_ba1fa_row10_col3, #T_ba1fa_row10_col4, #T_ba1fa_row11_col2, #T_ba1fa_row11_col3, #T_ba1fa_row11_col4, #T_ba1fa_row12_col2, #T_ba1fa_row12_col3, #T_ba1fa_row12_col4, #T_ba1fa_row13_col2, #T_ba1fa_row13_col3, #T_ba1fa_row13_col4, #T_ba1fa_row14_col2, #T_ba1fa_row14_col3, #T_ba1fa_row14_col4, #T_ba1fa_row15_col1, #T_ba1fa_row15_col2, #T_ba1fa_row15_col3, #T_ba1fa_row15_col4, #T_ba1fa_row16_col1, #T_ba1fa_row16_col2, #T_ba1fa_row16_col3, #T_ba1fa_row16_col4, #T_ba1fa_row17_col2, #T_ba1fa_row17_col3, #T_ba1fa_row17_col4 {
#   background-color: white;
# }
# </style>
# <table id="T_ba1fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba1fa_level0_col0" class="col_heading level0 col0" >Difference</th>
#       <th id="T_ba1fa_level0_col1" class="col_heading level0 col1" >t_statistic</th>
#       <th id="T_ba1fa_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_ba1fa_level0_col3" class="col_heading level0 col3" >Pair</th>
#       <th id="T_ba1fa_level0_col4" class="col_heading level0 col4" >Model</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba1fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba1fa_row0_col0" class="data row0 col0" >-3222799750.795904</td>
#       <td id="T_ba1fa_row0_col1" class="data row0 col1" >-52.799793</td>
#       <td id="T_ba1fa_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_ba1fa_row0_col3" class="data row0 col3" >Male-Female</td>
#       <td id="T_ba1fa_row0_col4" class="data row0 col4" >LinearRegression</td>
#     </tr>
#     <tr>
#       <th id="T_ba1fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ba1fa_row1_col0" class="data row1 col0" >3021896685.006815</td>
#       <td id="T_ba1fa_row1_col1" class="data row1 col1" >49.508357</td>
#       <td id="T_ba1fa_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_ba1fa_row1_col3" class="data row1 col3" >Male-Missing</td>
#       <td id="T_ba1fa_row1_col4" class="data row1 col4" >LinearRegression</td>
#     </tr>
#     <tr>
#       <th id="T_ba1fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ba1fa_row2_col0" class="data row2 col0" >6244696435.802719</td>
#       <td id="T_ba1fa_row2_col1" class="data row2 col1" >102.308150</td>
#       <td id="T_ba1fa_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_ba1fa_row2_col3" class="data row2 col3" >Female-Missing</td>
#       <td id="T_ba1fa_row2_col4" class="data row2 col4" >LinearRegression</td>
#     </tr>
#     <tr>
#       <th id="T_ba1fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ba1fa_row3_col0" class="data row3 col0" >0.001651</td>
#       <td id="T_ba1fa_row3_col1" class="data row3 col1" >0.077571</td>
#       <td id="T_ba1fa_row3_col2" class="data row3 col2" >0.938175</td>
#       <td id="T_ba1fa_row3_col3" class="data row3 col3" >Male-Female</td>
#       <td id="T_ba1fa_row3_col4" class="data row3 col4" >RandomForest</td>
#     </tr>
#     <tr>
#       <th id="T_ba1fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ba1fa_row4_col0" class="data row4 col0" >0.000567</td>
#       <td id="T_ba1fa_row4_col1" class="data row4 col1" >0.026657</td>
#       <td id="T_ba1fa_row4_col2" class="data row4 col2" >0.978735</td>
#       <td id="T_ba1fa_row4_col3" class="data row4 col3" >Male-Missing</td>
#       <td id="T_ba1fa_row4_col4" class="data row4 col4" >RandomForest</td>
#     </tr>
#     <tr>
#       <th id="T_ba1fa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ba1fa_row5_col0" class="data row5 col0" >-0.001084</td>
#       <td id="T_ba1fa_row5_col1" class="data row5 col1" >-0.050920</td>
#       <td id="T_ba1fa_row5_col2" class="data row5 col2" >0.959393</td>
#       <td id="T_ba1fa_row5_col3" class="data row5 col3" >Female-Missing</td>
#       <td id="T_ba1fa_row5_col4" class="data row5 col4" >RandomForest</td>
#     </tr>
#     <tr>
#       <th id="T_ba1fa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ba1fa_row6_col0" class="data row6 col0" >-0.000840</td>
#       <td id="T_ba1fa_row6_col1" class="data row6 col1" >-0.039117</td>
#       <td id="T_ba1fa_row6_col2" class="data row6 col2" >0.968800</td>
#       <td id="T_ba1fa_row6_col3" class="data row6 col3" >Male-Female</td>
#       <td id="T_ba1fa_row6_col4" class="data row6 col4" >XGBoost</td>
#     </tr>
#     <tr>
#       <th id="T_ba1fa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ba1fa_row7_col0" class="data row7 col0" >-0.000840</td>
#       <td id="T_ba1fa_row7_col1" class="data row7 col1" >-0.039117</td>
#       <td id="T_ba1fa_row7_col2" class="data row7 col2" >0.968800</td>
#       <td id="T_ba1fa_row7_col3" class="data row7 col3" >Male-Missing</td>
#       <td id="T_ba1fa_row7_col4" class="data row7 col4" >XGBoost</td>
#     </tr>
#     <tr>
#       <th id="T_ba1fa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ba1fa_row8_col0" class="data row8 col0" >0.000000</td>
#       <td id="T_ba1fa_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_ba1fa_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_ba1fa_row8_col3" class="data row8 col3" >Female-Missing</td>
#       <td id="T_ba1fa_row8_col4" class="data row8 col4" >XGBoost</td>
#     </tr>
#     <tr>
#       <th id="T_ba1fa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ba1fa_row9_col0" class="data row9 col0" >0.000008</td>
#       <td id="T_ba1fa_row9_col1" class="data row9 col1" >0.000354</td>
#       <td id="T_ba1fa_row9_col2" class="data row9 col2" >0.999717</td>
#       <td id="T_ba1fa_row9_col3" class="data row9 col3" >Male-Female</td>
#       <td id="T_ba1fa_row9_col4" class="data row9 col4" >LightGBM</td>
#     </tr>
#     <tr>
#       <th id="T_ba1fa_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ba1fa_row10_col0" class="data row10 col0" >0.000008</td>
#       <td id="T_ba1fa_row10_col1" class="data row10 col1" >0.000354</td>
#       <td id="T_ba1fa_row10_col2" class="data row10 col2" >0.999717</td>
#       <td id="T_ba1fa_row10_col3" class="data row10 col3" >Male-Missing</td>
#       <td id="T_ba1fa_row10_col4" class="data row10 col4" >LightGBM</td>
#     </tr>
#     <tr>
#       <th id="T_ba1fa_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ba1fa_row11_col0" class="data row11 col0" >0.000000</td>
#       <td id="T_ba1fa_row11_col1" class="data row11 col1" >0.000000</td>
#       <td id="T_ba1fa_row11_col2" class="data row11 col2" >1.000000</td>
#       <td id="T_ba1fa_row11_col3" class="data row11 col3" >Female-Missing</td>
#       <td id="T_ba1fa_row11_col4" class="data row11 col4" >LightGBM</td>
#     </tr>

# %% [markdown]
# # old graphs

# %%
for j, model in enumerate(models):
    y_pred = y_preds[j]
    
    
    plt.figure(figsize=(12, 6))
    plt.suptitle(model)

    # Create three subplots in a 1x3 grid
    for i, idx in enumerate(indices):
    
        y_pred_sel, y_true_sel = y_pred[idx], y_true[idx]

        # Sort the data and get the sorted indices
        sorted_indices = np.argsort(y_true_sel)

        # Sort y_true and y_pred based on the sorted indices
        y_true_sorted = np.array(y_true_sel)[sorted_indices]
        y_pred_sorted = np.array(y_pred_sel)[sorted_indices]

        # Create a scatterplot
        plt.scatter(range(len(y_true_sorted)), y_pred_sorted, c=colors[i], marker='o', label=titles[i], alpha=0.6, s=5)
        if i==2:
            plt.scatter(range(len(y_true_sorted)), y_true_sorted, c='black', marker='s', label='True value', alpha=1, s=3)
        plt.xlabel('Sorted Index')
        plt.ylabel('Interest Rate')
        #plt.title(titles[i])
        plt.legend(loc='upper left' )
        plt.grid(True)
        plt.tight_layout()

    plt.show()
    plt.clf()

# %%
# VECCHIO !!!!
plt.figure(figsize=(12, 8))

for i, idx in enumerate(indices[:-1]):    #idx_miss, 
    print(i)
    y_pred_sel, y_true_sel = y_pred[idx] , y_true[idx]
    
    # Sort the data and get the sorted indices
    sorted_indices = np.argsort(y_true_sel)

    # Sort y_true and y_pred based on the sorted indices
    y_true_sorted = np.array(y_true_sel)[sorted_indices]
    y_pred_sorted = np.array(y_pred_sel)[sorted_indices]

    # Create a scatterplot
    plt.scatter(range(len(y_true_sorted)), y_pred_sorted, c=colors[i], marker='o', label=titles[i], alpha=1, s=5)
    
    plt.xlabel('Sorted Index')
    plt.ylabel('Interest Rate')
    plt.title('Scatter Plot of y_true vs. y_pred: '+ model)
    plt.legend()

# plot y_true    
plt.scatter(range(len(y_true_sorted)), y_true_sorted, c='black', marker='s', label='y_true', alpha=0.3, s=3)    
# Show the plot
plt.grid(True)
plt.show()
# Out:
# 0
# 1
